# %%
import warnings 
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd 
from scipy import stats
import matplotlib.pyplot as plt

# %%
astro = pd.read_csv('astronauts.csv')
astro.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
astro['Birth Date'] = pd.to_datetime(astro['Birth Date'])

# %%
astro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    datetime64[ns]
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
astro.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
astro.duplicated().sum()
# Out:
# 0

# %%
astro2 = pd.read_csv('astronauts.csv',usecols=['Name','Status','Birth Date','Birth Place','Gender','Alma Mater','Space Flights','Space Flight (hr)','Space Walks','Space Walks (hr)','Missions'])
astro2
# Out:
#                       Name   Status Birth Date        Birth Place Gender  \
# 0          Joseph M. Acaba   Active  5/17/1967      Inglewood, CA   Male
# 1           Loren W. Acton  Retired   3/7/1936       Lewiston, MT   Male
# 2         James C. Adamson  Retired   3/3/1946         Warsaw, NY   Male
# 3          Thomas D. Akers  Retired  5/20/1951      St. Louis, MO   Male
# 4              Buzz Aldrin  Retired  1/20/1930      Montclair, NJ   Male
# ..                     ...      ...        ...                ...    ...
# 352          David A. Wolf  Retired  8/23/1956   Indianapolis, IN   Male
# 353  Neil W. Woodward III   Retired  7/26/1962        Chicago, IL   Male
# 354       Alfred M. Worden  Retired   2/7/1932        Jackson, MI   Male
# 355          John W. Young  Retired  9/24/1930  San Francisco, CA   Male
# 356        George D. Zamka  Retired  6/29/1962    Jersey City, NJ   Male
#
#                                             Alma Mater  Space Flights  \
# ...

# %%
astro2['Birth Date'] = pd.to_datetime(astro2['Birth Date'])

# %%
astro2.sample(5)
# Out:
#                      Name      Status Birth Date     Birth Place  Gender  \
# 111      C. Michael Foale      Active 1957-01-06  Louth, England    Male
# 113    Michael J. Foreman  Management 1957-03-29    Columbus, OH    Male
# 337         Mary E. Weber     Retired 1962-08-24   Cleveland, OH  Female
# 120  Ronald J. Garan Jr.   Management 1961-10-20     Yonkers, NY    Male
# 314      Joseph R. Tanner     Retired 1950-01-21    Danville, IL    Male
#
#                                             Alma Mater  Space Flights  \
# 111                               Cambridge University              6
# 113     US Naval Academy; US Naval Postgraduate School              2
# 337  Purdue University; University of California-Be...              2
# 120  State University of New York; Embry-Riddle Aer...              2
# 314                             University of Illinois              4
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# ...

# %%
astro2.Status.value_counts()
# Out:
# Status
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: count, dtype: int64

# %%
astro2.Gender.value_counts()
# Out:
# Gender
# Male      307
# Female     50
# Name: count, dtype: int64

# %%
astro2[astro2['Gender']=='Female']
# Out:
#                                 Name      Status Birth Date  \
# 17                   Serena M. Aunon      Active 1976-04-09
# 19                    Ellen S. Baker     Retired 1953-04-27
# 50                   Yvonne D. Cagle  Management 1959-04-24
# 52         Tracy E. Caldwell (Dyson)      Active 1969-08-14
# 67                    Kalpana Chawla    Deceased 1961-06-01
# 70                   Laurel B. Clark    Deceased 1961-03-10
# 71                    Mary L. Cleave     Retired 1947-02-05
# 75              Catherine G. Coleman      Active 1960-12-14
# 76                 Eileen M. Collins     Retired 1959-11-19
# 88                   Nancy J. Currie  Management 1958-12-29
# 89                      N. Jan Davis     Retired 1953-11-01
# 94                  Bonnie J. Dunbar     Retired 1949-03-03
# 101                 Jeanette J. Epps      Active 1970-11-03
# 109                   Anna L. Fisher  Management 1949-08-24
# 131                  Linda M. Godwin     Retired 1952-07-02
# ...

# %%
#female astronaut who are active
astro2[(astro2['Gender']=='Female')&(astro2['Status']=='Active')]
# Out:
#                                 Name  Status Birth Date           Birth Place  \
# 17                   Serena M. Aunon  Active 1976-04-09      Indianapolis, IN
# 52         Tracy E. Caldwell (Dyson)  Active 1969-08-14           Arcadia, CA
# 75              Catherine G. Coleman  Active 1960-12-14        Charleston, SC
# 101                 Jeanette J. Epps  Active 1970-11-03          Syracuse, NY
# 217                K. Megan McArthur  Active 1971-08-30          Honolulu, HI
# 231  Dorothy M. Metcalf-Lindenberger  Active 1975-05-02  Colorado Springs, CO
# 244                  Karen L. Nyberg  Active 1969-10-07  Parker’s Prairie, MN
# 280                  Kathleen Rubins  Active 1978-10-14        Farmington, CT
# 308                  Nicole P. Stott  Active 1962-11-19            Albany, NY
# 334                   Shannon Walker  Active 1965-06-04           Houston, TX
# 342                 Peggy A. Whitson  Active 1960-02-09           Mt. Ayr, IA
# ...

# %%
#female astronaut who are deceased
astro2[(astro2['Gender']=='Female')&(astro2['Status']=='Deceased')]
# Out:
#                             Name    Status Birth Date      Birth Place  \
# 67                Kalpana Chawla  Deceased 1961-06-01    Karnal, India
# 70               Laurel B. Clark  Deceased 1961-03-10         Ames, IA
# 219         S. Christa McAuliffe  Deceased 1948-09-02       Boston, MA
# 271             Judith A. Resnik  Deceased 1949-04-05        Akron, OH
# 274                Sally K. Ride  Deceased 1951-05-26  Los Angeles, CA
# 275  Patricia Hilliard Robertson  Deceased 1963-03-12      Indiana, PA
# 330               Janice E. Voss  Deceased 1956-10-08   South Bend, IN
#
#      Gender                                         Alma Mater  Space Flights  \
# 67   Female  Punjab Engineering College; University of Texa...              2
# 70   Female                    University of Wisconsin-Madison              1
# 219  Female      Framingham State College; Bowie State College              1
# 271  Female  Carnegie-Mellon University; University of Mary...              2
# ...

# %%
filtered_df = astro2[astro2['Gender'] == 'Female']
sorted_df = filtered_df.sort_values(by='Space Flights',ascending=False)
sorted_df
# Out:
#                                 Name      Status Birth Date  \
# 211                 Shannon W. Lucid     Retired 1943-01-14
# 172                  Marsha S. Ivins     Retired 1951-04-15
# 153                   Susan J. Helms     Retired 1958-02-26
# 94                  Bonnie J. Dunbar     Retired 1949-03-03
# 175               Tamara E. Jernigan     Retired 1959-05-07
# 330                   Janice E. Voss    Deceased 1956-10-08
# 247                      Ellen Ochoa  Management 1958-05-10
# 76                 Eileen M. Collins     Retired 1959-11-19
# 319              Kathryn C. Thornton     Retired 1952-08-17
# 131                  Linda M. Godwin     Retired 1952-07-02
# 189                Wendy B. Lawrence     Retired 1959-07-02
# 88                   Nancy J. Currie  Management 1958-12-29
# 310              Kathryn D. Sullivan     Retired 1951-10-03
# 292             Margaret Rhea Seddon     Retired 1947-11-08
# 229                 Pamela A. Melroy     Retired 1961-09-17
# ...

# %%
filtered_df['Space Flights'].min()
# Out:
# 0

# %%
filtered_df['Space Flights'].max()
# Out:
# 5

# %%
astro2[(astro2['Gender']=='Female')&(astro2['Space Flights'].max())]
# Out:
#                                 Name      Status Birth Date  \
# 17                   Serena M. Aunon      Active 1976-04-09
# 19                    Ellen S. Baker     Retired 1953-04-27
# 50                   Yvonne D. Cagle  Management 1959-04-24
# 52         Tracy E. Caldwell (Dyson)      Active 1969-08-14
# 67                    Kalpana Chawla    Deceased 1961-06-01
# 70                   Laurel B. Clark    Deceased 1961-03-10
# 71                    Mary L. Cleave     Retired 1947-02-05
# 75              Catherine G. Coleman      Active 1960-12-14
# 76                 Eileen M. Collins     Retired 1959-11-19
# 88                   Nancy J. Currie  Management 1958-12-29
# 89                      N. Jan Davis     Retired 1953-11-01
# 94                  Bonnie J. Dunbar     Retired 1949-03-03
# 101                 Jeanette J. Epps      Active 1970-11-03
# 109                   Anna L. Fisher  Management 1949-08-24
# 131                  Linda M. Godwin     Retired 1952-07-02
# ...

# %%
filtered_df = astro2[astro2['Gender'] == 'Female']
min_index = filtered_df['Space Flights'].idxmin()
min_row = filtered_df.loc[min_index]
min_row
# Out:
# Name                                                   Serena M. Aunon
# Status                                                          Active
# Birth Date                                         1976-04-09 00:00:00
# Birth Place                                           Indianapolis, IN
# Gender                                                          Female
# Alma Mater           George Washington University; University of Texas
# Space Flights                                                        0
# Space Flight (hr)                                                    0
# Space Walks                                                          0
# Space Walks (hr)                                                   0.0
# Missions                                                           NaN
# Name: 17, dtype: object

# %%
filtered_df = astro2[astro2['Gender'] == 'Female']
max_index = filtered_df['Space Flights'].idxmax()
max_row = filtered_df.loc[max_index]
max_row
# Out:
# Name                                                  Bonnie J. Dunbar
# Status                                                         Retired
# Birth Date                                                    3/3/1949
# Birth Place                                              Sunnyside, WA
# Gender                                                          Female
# Alma Mater             University of Washington; University of Houston
# Space Flights                                                        5
# Space Flight (hr)                                                 1207
# Space Walks                                                          0
# Space Walks (hr)                                                   0.0
# Missions             STS 61-A (Challenger), STS-32 (Columbia), STS-...
# Name: 94, dtype: object

# %%
filtered_df = astro2[astro2['Gender'] == 'Male']
min_index = filtered_df['Space Flights'].idxmin()
min_row = filtered_df.loc[min_index]
min_row
# Out:
# Name                      Charles A. Bassett II
# Status                                  Deceased
# Birth Date                            12/30/1931
# Birth Place                           Dayton, OH
# Gender                                      Male
# Alma Mater           Texas Technological College
# Space Flights                                  0
# Space Flight (hr)                              0
# Space Walks                                    0
# Space Walks (hr)                             0.0
# Missions                                     NaN
# Name: 24, dtype: object

# %%
filtered_df = astro2[astro2['Gender'] == 'Male']
max_index = filtered_df['Space Flights'].idxmax()
max_row = filtered_df.loc[max_index]
max_row
# Out:
# Name                                            Franklin R. Chang-Diaz
# Status                                                         Retired
# Birth Date                                                    4/5/1950
# Birth Place                                       San Jose, Costa Rica
# Gender                                                            Male
# Alma Mater                              University of Connecticut; MIT
# Space Flights                                                        7
# Space Flight (hr)                                                 1602
# Space Walks                                                          3
# Space Walks (hr)                                                  19.0
# Missions             STS 61-C (Columbia), STS-34 (Atlantis), STS-46...
# Name: 65, dtype: object

# %% [markdown]
# # Female Astronaut

# %%
female_astro = astro2[astro2['Gender']=='Female']
female_astro
# Out:
#                                 Name      Status  Birth Date  \
# 17                   Serena M. Aunon      Active    4/9/1976
# 19                    Ellen S. Baker     Retired   4/27/1953
# 50                   Yvonne D. Cagle  Management   4/24/1959
# 52         Tracy E. Caldwell (Dyson)      Active   8/14/1969
# 67                    Kalpana Chawla    Deceased    6/1/1961
# 70                   Laurel B. Clark    Deceased   3/10/1961
# 71                    Mary L. Cleave     Retired    2/5/1947
# 75              Catherine G. Coleman      Active  12/14/1960
# 76                 Eileen M. Collins     Retired  11/19/1959
# 88                   Nancy J. Currie  Management  12/29/1958
# 89                      N. Jan Davis     Retired   11/1/1953
# 94                  Bonnie J. Dunbar     Retired    3/3/1949
# 101                 Jeanette J. Epps      Active   11/3/1970
# 109                   Anna L. Fisher  Management   8/24/1949
# ...

# %%
female_astro['Birth Date'] = pd.to_datetime(female_astro['Birth Date'])

# %%
female_astro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 17 to 349
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               50 non-null     object
#  1   Status             50 non-null     object
#  2   Birth Date         50 non-null     datetime64[ns]
#  3   Birth Place        50 non-null     object
#  4   Gender             50 non-null     object
#  5   Alma Mater         50 non-null     object
#  6   Space Flights      50 non-null     int64
#  7   Space Flight (hr)  50 non-null     int64
#  8   Space Walks        50 non-null     int64
#  9   Space Walks (hr)   50 non-null     float64
#  10  Missions           46 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 4.7+ KB

# %%
female_astro.Status.value_counts()
# Out:
# Status
# Retired       24
# Active        13
# Deceased       7
# Management     6
# Name: count, dtype: int64

# %%
#female astronaut who are active and date of birth sorted
female_astro[female_astro['Status']=='Active'].sort_values(by='Birth Date')
# Out:
#                                 Name  Status Birth Date           Birth Place  \
# 342                 Peggy A. Whitson  Active 1960-02-09           Mt. Ayr, IA
# 75              Catherine G. Coleman  Active 1960-12-14        Charleston, SC
# 308                  Nicole P. Stott  Active 1962-11-19            Albany, NY
# 334                   Shannon Walker  Active 1965-06-04           Houston, TX
# 347               Sunita L. Williams  Active 1965-09-19            Euclid, OH
# 349              Stephanie D. Wilson  Active 1966-09-27            Boston, MA
# 52         Tracy E. Caldwell (Dyson)  Active 1969-08-14           Arcadia, CA
# 244                  Karen L. Nyberg  Active 1969-10-07  Parker’s Prairie, MN
# 101                 Jeanette J. Epps  Active 1970-11-03          Syracuse, NY
# 217                K. Megan McArthur  Active 1971-08-30          Honolulu, HI
# 231  Dorothy M. Metcalf-Lindenberger  Active 1975-05-02  Colorado Springs, CO
# ...

# %%
#female astronaut who are Deceased sorted DOB
female_astro[female_astro['Status']=='Deceased'].sort_values(by='Birth Date')
# Out:
#                             Name    Status Birth Date      Birth Place  \
# 219         S. Christa McAuliffe  Deceased 1948-09-02       Boston, MA
# 271             Judith A. Resnik  Deceased 1949-04-05        Akron, OH
# 274                Sally K. Ride  Deceased 1951-05-26  Los Angeles, CA
# 330               Janice E. Voss  Deceased 1956-10-08   South Bend, IN
# 70               Laurel B. Clark  Deceased 1961-03-10         Ames, IA
# 67                Kalpana Chawla  Deceased 1961-06-01    Karnal, India
# 275  Patricia Hilliard Robertson  Deceased 1963-03-12      Indiana, PA
#
#      Gender                                         Alma Mater  Space Flights  \
# 219  Female      Framingham State College; Bowie State College              1
# 271  Female  Carnegie-Mellon University; University of Mary...              2
# 274  Female                                Stanford University              2
# 330  Female                             Purdue University; MIT              5
# ...

# %%
#female astronaut who doing most of the number of space flight
female_astro.sort_values(by='Space Flights').tail(5)
# Out:
#                    Name    Status Birth Date      Birth Place  Gender  \
# 172     Marsha S. Ivins   Retired 1951-04-15    Baltimore, MD  Female
# 330      Janice E. Voss  Deceased 1956-10-08   South Bend, IN  Female
# 175  Tamara E. Jernigan   Retired 1959-05-07  Chattanooga, TN  Female
# 211    Shannon W. Lucid   Retired 1943-01-14  Shanghai, China  Female
# 94     Bonnie J. Dunbar   Retired 1949-03-03    Sunnyside, WA  Female
#
#                                             Alma Mater  Space Flights  \
# 172                             University of Colorado              5
# 330                             Purdue University; MIT              5
# 175  Stanford University; University of California-...              5
# 211                             University of Oklahoma              5
# 94     University of Washington; University of Houston              5
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 172               1341            0               0.0
# ...

# %%
#Top 5 female astronaut who have least space flight numbers
female_astro.sort_values(by='Space Flights').head(5)
# Out:
#                             Name      Status Birth Date       Birth Place  \
# 17               Serena M. Aunon      Active 1976-04-09  Indianapolis, IN
# 50               Yvonne D. Cagle  Management 1959-04-24    West Point, NY
# 275  Patricia Hilliard Robertson    Deceased 1963-03-12       Indiana, PA
# 101             Jeanette J. Epps      Active 1970-11-03      Syracuse, NY
# 219         S. Christa McAuliffe    Deceased 1948-09-02        Boston, MA
#
#      Gender                                         Alma Mater  Space Flights  \
# 17   Female  George Washington University; University of Texas              0
# 50   Female                     San Francisco State University              0
# 275  Female  Indiana University of Pennsylvania; Medical Co...              0
# 101  Female            LeMoyne College; University of Maryland              0
# 219  Female      Framingham State College; Bowie State College              1
#
# ...

# %%
#youngest astronaut according to dataset
female_astro.sort_values(by='Birth Date',ascending=True).tail(1)
# Out:
#                 Name  Status Birth Date     Birth Place  Gender  \
# 280  Kathleen Rubins  Active 1978-10-14  Farmington, CT  Female
#
#                                             Alma Mater  Space Flights  \
# 280  University of California-San Diego; Stanford U...              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)           Missions
# 280               2762            2              13.0  ISS-48/49 (Soyuz)

# %%
#oldest astronaut according to dataset
female_astro.sort_values(by='Birth Date').head(1)
# Out:
#                  Name   Status Birth Date      Birth Place  Gender  \
# 211  Shannon W. Lucid  Retired 1943-01-14  Shanghai, China  Female
#
#                  Alma Mater  Space Flights  Space Flight (hr)  Space Walks  \
# 211  University of Oklahoma              5               5354            0
#
#      Space Walks (hr)                                           Missions
# 211               0.0  STS 51-G (Discovery), STS-34 (Atlantis), STS-4...

# %%
#female astronaut who spend most of the time in Space Flight in hour
female_astro.sort_values(by='Space Flight (hr)').tail(1)
# Out:
#                  Name  Status Birth Date  Birth Place  Gender  \
# 342  Peggy A. Whitson  Active 1960-02-09  Mt. Ayr, IA  Female
#
#                                  Alma Mater  Space Flights  Space Flight (hr)  \
# 342  Iowa Wesleyan College; Rice University              3              11698
#
#      Space Walks  Space Walks (hr)  \
# 342            7              46.0
#
#                                               Missions
# 342  STS-111/113 (Endeavor), ISS-16 (Soyuz), ISS-50...

# %%
#female astronaut who doing most of the space walk 
female_astro.sort_values(by='Space Walks').tail(1)
# Out:
#                    Name  Status Birth Date Birth Place  Gender  \
# 347  Sunita L. Williams  Active 1965-09-19  Euclid, OH  Female
#
#                                             Alma Mater  Space Flights  \
# 347  US Naval Academy; Florida Institute of Technology              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 347               7721            7              50.0
#
#                                               Missions
# 347  STS-116/117 (Discovery/Atlantis), ISS-32/33 (S...

# %%
#female astronaut who doing most of the space walk in hours
female_astro.sort_values(by='Space Walks (hr)').tail(1)
# Out:
#                    Name  Status Birth Date Birth Place  Gender  \
# 347  Sunita L. Williams  Active 1965-09-19  Euclid, OH  Female
#
#                                             Alma Mater  Space Flights  \
# 347  US Naval Academy; Florida Institute of Technology              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 347               7721            7              50.0
#
#                                               Missions
# 347  STS-116/117 (Discovery/Atlantis), ISS-32/33 (S...

# %% [markdown]
# # Male Astronaut

# %%
male_astro = astro2[astro2['Gender']=='Male']
male_astro['Birth Date'] = pd.to_datetime(male_astro['Birth Date'])
male_astro
# Out:
#                       Name   Status Birth Date        Birth Place Gender  \
# 0          Joseph M. Acaba   Active 1967-05-17      Inglewood, CA   Male
# 1           Loren W. Acton  Retired 1936-03-07       Lewiston, MT   Male
# 2         James C. Adamson  Retired 1946-03-03         Warsaw, NY   Male
# 3          Thomas D. Akers  Retired 1951-05-20      St. Louis, MO   Male
# 4              Buzz Aldrin  Retired 1930-01-20      Montclair, NJ   Male
# ..                     ...      ...        ...                ...    ...
# 352          David A. Wolf  Retired 1956-08-23   Indianapolis, IN   Male
# 353  Neil W. Woodward III   Retired 1962-07-26        Chicago, IL   Male
# 354       Alfred M. Worden  Retired 1932-02-07        Jackson, MI   Male
# 355          John W. Young  Retired 1930-09-24  San Francisco, CA   Male
# 356        George D. Zamka  Retired 1962-06-29    Jersey City, NJ   Male
#
#                                             Alma Mater  Space Flights  \
# ...

# %%
male_astro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307 entries, 0 to 356
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               307 non-null    object
#  1   Status             307 non-null    object
#  2   Birth Date         307 non-null    datetime64[ns]
#  3   Birth Place        307 non-null    object
#  4   Gender             307 non-null    object
#  5   Alma Mater         306 non-null    object
#  6   Space Flights      307 non-null    int64
#  7   Space Flight (hr)  307 non-null    int64
#  8   Space Walks        307 non-null    int64
#  9   Space Walks (hr)   307 non-null    float64
#  10  Missions           288 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 28.8+ KB

# %%
male_astro.Status.value_counts()
# Out:
# Status
# Retired       196
# Deceased       44
# Active         37
# Management     30
# Name: count, dtype: int64

# %%
male_astro[male_astro['Status']=='Active'].sort_values(by='Birth Date')
# Out:
#                        Name  Status Birth Date       Birth Place Gender  \
# 261        Donald R. Pettit  Active 1955-04-20     Silverton, OR   Male
# 111        C. Michael Foale  Active 1957-01-06    Louth, England   Male
# 115       Michael E. Fossum  Active 1957-12-19   Sioux Falls, SD   Male
# 346     Jeffrey N. Williams  Active 1958-01-18      Superior, WI   Male
# 21       Michael R. Barratt  Active 1959-04-16     Vancouver, WA   Male
# 215  Richard A. Mastracchio  Active 1960-02-11     Waterbury, CT   Male
# 340     Douglas H. Wheelock  Active 1960-05-05    Binghamton, NY   Male
# 112           Kevin A. Ford  Active 1960-07-07      Portland, IN   Male
# 213     Thomas H. Marshburn  Active 1960-08-29   Statesville, NC   Male
# 311       Steven R. Swanson  Active 1960-12-03      Syracuse, NY   Male
# 47        Daniel C. Burbank  Active 1961-07-27     Machester, CT   Male
# 178      Gregory H. Johnson  Active 1962-05-12   London, England   Male
# ...

# %%
#most top 5 aged male astronaut
male_astro.sort_values(by='Birth Date').head(5)
# Out:
#                        Name    Status Birth Date     Birth Place Gender  \
# 130      John H. Glenn Jr.    Retired 1921-07-18   Cambridge, OH   Male
# 284  Walter M. Schirra Jr.   Deceased 1923-03-12  Hackensack, NJ   Male
# 297    Alan B. Shepard Jr.   Deceased 1923-11-18  East Derry, NH   Male
# 300       Donald K. Slayton  Deceased 1924-03-01      Sparta, WI   Male
# 56       M. Scott Carpenter   Retired 1925-05-01     Boulder, CO   Male
#
#                   Alma Mater  Space Flights  Space Flight (hr)  Space Walks  \
# 130        Muskingum College              2                218            0
# 284         US Naval Academy              3                295            0
# 297         US Naval Academy              2                216            2
# 300  University of Minnesota              1                217            0
# 56    University of Colorado              1                  4            0
#
#      Space Walks (hr)                       Missions
# ...

# %%
#most young astronaut in dataset
male_astro.sort_values(by='Birth Date').tail(1)
# Out:
#                 Name  Status Birth Date    Birth Place Gender  \
# 350  G. Reid Wiseman  Active 1975-11-11  Baltimore, MD   Male
#
#                                             Alma Mater  Space Flights  \
# 350  Rensselaer Polytechnic Institute; Johns Hopkin...              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)           Missions
# 350               3968            2              13.0  ISS-40/41 (Soyuz)

# %%
#most spend time in space in hours
male_astro.sort_values(by='Space Flight (hr)').tail(1)
# Out:
#                     Name  Status Birth Date   Birth Place Gender  \
# 346  Jeffrey N. Williams  Active 1958-01-18  Superior, WI   Male
#
#                                             Alma Mater  Space Flights  \
# 346  US Military Academy; US Naval Postgraduate Sch...              4
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 346              12818            5              32.0
#
#                                               Missions
# 346  STS-101 (Atlantis), ISS-13 (Soyuz), ISS-21/22 ...

# %%
#male astronaut who have most space flight
male_astro.sort_values(by='Space Flights').tail(1)
# Out:
#               Name   Status Birth Date      Birth Place Gender  \
# 279  Jerry L. Ross  Retired 1948-01-20  Crown Point, IN   Male
#
#             Alma Mater  Space Flights  Space Flight (hr)  Space Walks  \
# 279  Purdue University              7               1393            9
#
#      Space Walks (hr)                                           Missions
# 279              58.0  ST 61-B (Atlantis), ST-27 (Atlantis), ST-37 (A...

# %%
#male astronaut who doing longest space walk 
male_astro.sort_values(by='Space Walks').tail(1)
# Out:
#                          Name   Status Birth Date    Birth Place Gender  \
# 203  Michael E. Lopez-Alegria  Retired 1958-05-30  Madrid, Spain   Male
#
#                                          Alma Mater  Space Flights  \
# 203  US Naval Academy; US Naval Postgraduate School              3
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 203               6190           10              67.0
#
#                                               Missions
# 203  STS-73 (Columbia), STS-92 (Discovery), STS-113...

# %%
#male astronaut who doing longest space walk in hours
male_astro.sort_values(by='Space Walks (hr)').tail(1)
# Out:
#                          Name   Status Birth Date    Birth Place Gender  \
# 203  Michael E. Lopez-Alegria  Retired 1958-05-30  Madrid, Spain   Male
#
#                                          Alma Mater  Space Flights  \
# 203  US Naval Academy; US Naval Postgraduate School              3
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 203               6190           10              67.0
#
#                                               Missions
# 203  STS-73 (Columbia), STS-92 (Discovery), STS-113...

# %% [markdown]
# # now we find ceratin space mission astronaut

# %% [markdown]
# # astronaut of STS 51-L (Challenger)

# %%
astro2[astro2['Missions']=='STS 51-L (Challenger)']
# Out:
#                      Name    Status Birth Date   Birth Place  Gender  \
# 173     Gregory B. Jarvis  Deceased 1944-08-24   Detroit, MI    Male
# 219  S. Christa McAuliffe  Deceased 1948-09-02    Boston, MA  Female
# 301      Michael J. Smith  Deceased 1945-04-30  Beaufort, NC    Male
#
#                                             Alma Mater  Space Flights  \
# 173  State University of New York at Buffalo; North...              1
# 219      Framingham State College; Bowie State College              1
# 301     US Naval Academy; US Naval Postgraduate School              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)               Missions
# 173                  0            0               0.0  STS 51-L (Challenger)
# 219                  0            0               0.0  STS 51-L (Challenger)
# 301                  0            0               0.0  STS 51-L (Challenger)

# %%
astro2['Missions'].value_counts()
# Out:
# Missions
# STS 51-F (Challenger)                       5
# STS-83 (Columbia), STS-94 (Columbia)        3
# STS 51-B (Challenger)                       3
# STS-107 (Columbia)                          3
# Skylab 4                                    3
#                                            ..
# STS-8 (Challenger), STS 51-A (Discovery)    1
# STS-124 (Discovery), ISS-27/28 (Soyuz)      1
# STS-3 (Columbia), STS 51-F (Challenger)     1
# STS-110 (Atlantis), STS-122 (Atlantis)      1
# STS-120 (Discovery), STS-130 (Endeavor)     1
# Name: count, Length: 305, dtype: int64

# %%
astro2[astro2['Missions']=='STS 51-F (Challenger)']
# Out:
#                      Name    Status Birth Date       Birth Place Gender  \
# 1          Loren W. Acton   Retired 1936-03-07      Lewiston, MT   Male
# 23   John-David F. Bartoe   Retired 1944-11-17      Abington, PA   Male
# 40    Roy D. Bridges Jr.    Retired 1943-07-19       Atlanta, GA   Male
# 99     Anthony W. England   Retired 1942-05-15  Indianapolis, IN   Male
# 154        Karl G. Henize  Deceased 1926-10-17    Cincinnati, OH   Male
#
#                                            Alma Mater  Space Flights  \
# 1    Montana State University; University of Colorado              1
# 23           Lehigh University; Georgetown University              1
# 40            US Air Force Academy; Purdue University              1
# 99                                                MIT              1
# 154    University of Virginia; University of Michigan              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)               Missions
# ...

# %%
astro2[astro2['Missions']=='Skylab 4']
# Out:
#                  Name   Status Birth Date  Birth Place Gender  \
# 57     Gerald P. Carr  Retired 1932-08-22   Denver, CO   Male
# 127  Edward G. Gibson  Retired 1936-11-08  Buffalo, NY   Male
# 263  William R. Pogue  Retired 1930-01-23   Okemah, OK   Male
#
#                                             Alma Mater  Space Flights  \
# 57   University of Southern California; US Naval Po...              1
# 127  University of Rochester; California Institute ...              1
# 263  Oklahoma Baptist University; Oklahoma State Un...              1
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  Missions
# 57                2017            3              16.0  Skylab 4
# 127               2017            3              15.0  Skylab 4
# 263               2017            2              13.0  Skylab 4

# %%
astro2[astro2['Missions'].str.contains('Skylab', case=False, na=False)]
# Out:
#                     Name    Status Birth Date       Birth Place Gender  \
# 25          Alan L. Bean   Retired 1932-03-15       Wheeler, TX   Male
# 57        Gerald P. Carr   Retired 1932-08-22        Denver, CO   Male
# 78   Charles Conrad Jr.   Deceased 1930-05-02  Philadelphia, PA   Male
# 124     Owen K. Garriott   Retired 1930-11-22          Enid, OK   Male
# 127     Edward G. Gibson   Retired 1936-11-08       Buffalo, NY   Male
# 184     Joseph P. Kerwin   Retired 1932-02-19      Oak Park, IL   Male
# 206       Jack R. Lousma   Retired 1936-02-29  Grand Rapids, MI   Male
# 263     William R. Pogue   Retired 1930-01-23        Okemah, OK   Male
# 338        Paul J. Weitz   Retired 1932-06-25          Erie, PA   Male
#
#                                             Alma Mater  Space Flights  \
# 25                                 University of Texas              2
# 57   University of Southern California; US Naval Po...              1
# ...

# %%
astro2[astro2['Missions'].str.contains('Columbia', case=False, na=False)]
# Out:
#                     Name    Status Birth Date          Birth Place  Gender  \
# 2       James C. Adamson   Retired 1946-03-03           Warsaw, NY    Male
# 5        Andrew M. Allen   Retired 1955-08-04     Philadelphia, PA    Male
# 6        Joseph P. Allen   Retired 1937-06-27  Crawsfordsville, IN    Male
# 7        Scott D. Altman   Retired 1959-08-15          Lincoln, IL    Male
# 10   Michael P. Anderson  Deceased 1959-12-25      Plattsburgh, NY    Male
# ..                   ...       ...        ...                  ...     ...
# 330       Janice E. Voss  Deceased 1956-10-08       South Bend, IN  Female
# 335         Carl E. Walz   Retired 1955-09-06        Cleveland, OH    Male
# 339   James D. Wetherbee   Retired 1952-11-27         Flushing, NY    Male
# 352        David A. Wolf   Retired 1956-08-23     Indianapolis, IN    Male
# 355        John W. Young   Retired 1930-09-24    San Francisco, CA    Male
#
# ...

# %%
astro2.iloc[355]
# Out:
# Name                                                     John W. Young
# Status                                                         Retired
# Birth Date                                         1930-09-24 00:00:00
# Birth Place                                          San Francisco, CA
# Gender                                                            Male
# Alma Mater                             Georgia Institute of Technology
# Space Flights                                                        6
# Space Flight (hr)                                                  835
# Space Walks                                                          3
# Space Walks (hr)                                                  20.0
# Missions             Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...
# Name: 355, dtype: object

# %% [markdown]
# # Number of astronaut from MIT

# %%
mit = astro2[astro2['Alma Mater'].str.contains('MIT', case=False, na=False)]
print("Number of Astronaut from MIT = ",mit.Name.count())
mit
# Out:
# Number of Astronaut from MIT =  36
#                                 Name      Status Birth Date  \
# 4                        Buzz Aldrin     Retired 1930-01-20
# 11              Dominic A. Antonelli      Active 1967-08-23
# 12                   Jerome Apt III      Retired 1949-04-18
# 34                  Stephen G. Bowen      Active 1964-02-13
# 54                Kenneth D. Cameron     Retired 1949-11-29
# 60            Christopher J. Cassidy      Active 1970-01-04
# 64              Gregory E. Chamitoff      Active 1962-08-06
# 65            Franklin R. Chang-Diaz     Retired 1950-04-05
# 66                 Philip K. Chapman     Retired 1935-03-05
# 75              Catherine G. Coleman      Active 1960-12-14
# 81                Timothy J. Creamer  Management 1959-11-15
# 93              Charles M. Duke Jr.      Retired 1935-10-03
# 99                Anthony W. England     Retired 1942-05-15
# 107                E. Michael Fincke      Active 1967-03-14
# ...

# %% [markdown]
# # Number of astronaut from Harvard University

# %%
harvard = astro2[astro2['Alma Mater'].str.contains('Harvard University', case=False, na=False)]
print("Number of Astronaut from Harvard University = ",harvard.Name.count())
harvard
# Out:
# Number of Astronaut from Harvard University =  7
#                        Name      Status Birth Date      Birth Place  Gender  \
# 12          Jerome Apt III      Retired 1949-04-18  Springfield, MA    Male
# 164      Jeffrey A. Hoffman     Retired 1944-11-02     Brooklyn, NY    Male
# 199     Richard M. Linnehan  Management 1957-09-19       Lowell, MA    Male
# 204    Christopher J. Loria     Retired 1960-07-09      Belmont, MA    Male
# 283  Robert L. Satcher Jr.      Retired 1965-09-22      Hampton, VA    Male
# 285     Harrison H. Schmitt     Retired 1935-07-03   Santa Rita, NM    Male
# 349     Stephanie D. Wilson      Active 1966-09-27       Boston, MA  Female
#
#                                             Alma Mater  Space Flights  \
# 12                             Harvard University; MIT              4
# 164  Amherst College; Rice University; Harvard Univ...              5
# 199  University of New Hampshire; Ohio State Univer...              4
# ...

# %% [markdown]
# # Number of astronaut from California Institute of Technology

# %%
Cal = astro2[astro2['Alma Mater'].str.contains('California Institute of Technology', case=False, na=False)]
print("Number of Astronaut from CALTECH = ",Cal.Name.count())
Cal
# Out:
# Number of Astronaut from CALTECH =  11
#                      Name   Status Birth Date                 Birth Place  \
# 26      Robert L. Behnken   Active 1970-07-28             Creve Couer, MO
# 33           Frank Borman  Retired 1928-03-14                    Gary, IN
# 64   Gregory E. Chamitoff   Active 1962-08-06            Montreal, Canada
# 118   C. Gordon Fullerton  Retired 1936-10-11               Rochester, NY
# 127      Edward G. Gibson  Retired 1936-11-08                 Buffalo, NY
# 227         Carl J. Meade  Retired 1950-11-16  Chanute Air Force Base, IL
# 232      F. Curtis Michel  Retired 1934-06-05                LaCrosse, WI
# 256      Robert A. Parker  Retired 1936-12-14                New York, NY
# 270    Garrett E. Reisman  Retired 1968-02-10              Morristown, NJ
# 285   Harrison H. Schmitt  Retired 1935-07-03              Santa Rita, NM
# 291   Richard A. Searfoss  Retired 1956-06-05           Mount Clemens, MI
#
# ...

# %% [markdown]
# # Number of Astronaut from US Air Force Academy

# %%
USAir = astro2[astro2['Alma Mater'].str.contains('US Air Force Academy', case=False, na=False)]
print("Number of Astronaut from US Air Force Academy = ",USAir.Name.count())
USAir
# Out:
# Number of Astronaut from US Air Force Academy =  38
#                        Name      Status Birth Date        Birth Place  Gender  \
# 27            John E. Blaha     Retired 1942-08-26    San Antonio, TX    Male
# 28    Michael J. Bloomfield     Retired 1959-03-16          Flint, MI    Male
# 30           Karol J. Bobko     Retired 1937-12-23       New York, NY    Male
# 31              Eric A. Boe      Active 1964-10-01          Miami, FL    Male
# 40      Roy D. Bridges Jr.      Retired 1943-07-19        Atlanta, GA    Male
# 41     Curtis L. Brown Jr.      Retired 1956-03-11  Elizabethtown, NC    Male
# 59           John H. Casper  Management 1943-07-09     Greenville, SC    Male
# 69         Kevin P. Chilton     Retired 1954-03-11    Los Angeles, CA    Male
# 80         Richard O. Covey     Retired 1946-08-01   Fayetteville, AR    Male
# 91       Alvin B. Drew Jr.       Active 1962-11-05     Washington, DC    Male
# ...

# %% [markdown]
# # Astronaut from Columbia University

# %%
SU = astro2[astro2['Alma Mater'].str.contains('Columbia University', case=False, na=False)]
print("Number of Astronaut from Columbia University = ",SU.Name.count())
SU
# Out:
# Number of Astronaut from Columbia University =  6
#                      Name      Status Birth Date      Birth Place Gender  \
# 35    Kenneth D. Bowersox     Retired 1956-11-14   Portsmouth, VA   Male
# 69       Kevin P. Chilton     Retired 1954-03-11  Los Angeles, CA   Male
# 138    William G. Gregory     Retired 1957-05-14     Lockport, NY   Male
# 178    Gregory H. Johnson      Active 1962-05-12  London, England   Male
# 214  Michael J. Massimino  Management 1962-08-19    Oceanside, NY   Male
# 237        Story Musgrave     Retired 1935-08-19       Boston, MA   Male
#
#                                             Alma Mater  Space Flights  \
# 35               US Naval Academy; Columbia University              5
# 69           US Air Force Academy; Columbia University              3
# 138  US Air Force Academy; Columbia University; Tro...              1
# 178  US Air Force Academy; Columbia University; Uni...              2
# ...

# %% [markdown]
# # Astronaut from US Naval Academy

# %%
USN = astro2[astro2['Alma Mater'].str.contains('US Naval Academy', case=False, na=False)]
print("Number of Astronaut from US Naval Academy = ",USN.Name.count())
USN
# Out:
# Number of Astronaut from US Naval Academy =  52
#                           Name      Status Birth Date  \
# 8            William A. Anders     Retired 1933-10-17
# 32      Charles F. Bolden Jr.   Management 1946-08-19
# 34            Stephen G. Bowen      Active 1964-02-13
# 35         Kenneth D. Bowersox     Retired 1956-11-14
# 44             James F. Buchli     Retired 1945-06-20
# 48            Daniel W. Bursch     Retired 1957-07-25
# 49            Robert D. Cabana  Management 1949-01-23
# 60      Christopher J. Cassidy      Active 1970-01-04
# 73            Michael L. Coats     Retired 1946-01-16
# 82           John O. Creighton     Retired 1943-04-28
# 85    Frank L. Culbertson Jr.      Retired 1949-05-15
# 87      Robert L. Curbeam Jr.      Retired 1962-03-05
# 93        Charles M. Duke Jr.      Retired 1935-10-03
# 97         Joe F. Edwards Jr.      Retired 1958-02-03
# 98              Donn F. Eisele    Deceased 1930-05-23
# ...

# %% [markdown]
# # Basic Statistics of Alma Mater

# %%
print("Number of Astronaut from MIT = ",mit.Name.count())
print("Number of Astronaut from US Naval Academy = ",USN.Name.count())
print("Number of Astronaut from Columbia University = ",SU.Name.count())
print("Number of Astronaut from Harvard University = ",harvard.Name.count())
print("Number of Astronaut from US Air Force Academy = ",USAir.Name.count())
print("Number of Astronaut from IIT = ",iit.Name.count())
# Out:
# Number of Astronaut from MIT =  36
# Number of Astronaut from US Naval Academy =  52
# Number of Astronaut from Columbia University =  6
# Number of Astronaut from Harvard University =  7
# Number of Astronaut from US Air Force Academy =  38
# Number of Astronaut from IIT =  0

# %% [markdown]
# # From IIT

# %%
iit = astro2[astro2['Alma Mater'].str.contains('Indian Institute of Technology', case=False, na=False)]
print("Number of Astronaut from IIT = ",iit.Name.count())
iit
# Out:
# Number of Astronaut from IIT =  0
# Empty DataFrame
# Columns: [Name, Status, Birth Date, Birth Place, Gender, Alma Mater, Space Flights, Space Flight (hr), Space Walks, Space Walks (hr), Missions]
# Index: []
