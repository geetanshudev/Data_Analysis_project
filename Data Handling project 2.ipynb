# %% [markdown]
# # Data Handling on Song Datasets

# %%
#importing library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs = pd.read_csv("C:\\Users\\Geetanshu Dev\\Documents\\csv for EDA\\Song.csv")

# %%
songs.head(5)
# Out:
#                     Artist                              Title  Year   Sales  \
# 0  Bill Haley & his Comets              Rock Around the Clock  1955  36.503
# 1              Celine Dion                My Heart Will Go On  1998  35.405
# 2          Sinead O'Connor               Nothing Compares 2 U  1990  35.135
# 3              The Beatles                           Hey Jude  1968  34.442
# 4              Bryan Adams  (Everything I Do) I Do it For You  1991  34.367
#
#    Streams  Downloads  Radio Plays  Rating
# 0   19.961      7.458        5.663   0.760
# 1   12.636      8.944       23.701   3.610
# 2   14.582     10.242       23.747   2.733
# 3   25.545     16.390       16.541   1.510
# 4   16.523     12.368       23.194   3.121

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4850 entries, 0 to 4849
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Artist       4850 non-null   object
#  1   Title        4850 non-null   object
#  2   Year         4850 non-null   int64
#  3   Sales        4850 non-null   float64
#  4   Streams      4850 non-null   float64
#  5   Downloads    4850 non-null   float64
#  6   Radio Plays  4850 non-null   float64
#  7   Rating       4850 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 303.2+ KB

# %%
songs.describe()
# Out:
#               Year        Sales      Streams    Downloads  Radio Plays  \
# count  4850.000000  4850.000000  4850.000000  4850.000000  4850.000000
# mean   1979.861443     8.154870     4.628823     2.970114     3.985120
# std      19.759676     4.555715     3.273776     2.668744     4.354419
# min    1901.000000     4.149000     0.000000     0.000000     0.000000
# 25%    1967.000000     5.069250     2.351250     1.039500     0.600000
# 50%    1981.000000     6.438000     4.200000     2.200000     2.570000
# 75%    1996.000000     9.784000     6.307000     4.183750     5.884000
# max    2014.000000    36.503000    25.545000    19.780000    24.393000
#
#             Rating
# count  4850.000000
# mean      0.481876
# std       0.624719
# min       0.000000
# 25%       0.000000
# 50%       0.512000
# 75%       0.571000
# max       4.460000

# %%
print("Number of rows = ",songs.shape[0])
print("Number of columns = ",songs.shape[1])
# Out:
# Number of rows =  4850
# Number of columns =  8

# %% [raw]
# So our datasets have 4850 rows and 8 columns now we check if there is null data or not

# %%
songs.isnull().sum()
# Out:
# Artist         0
# Title          0
# Year           0
# Sales          0
# Streams        0
# Downloads      0
# Radio Plays    0
# Rating         0
# dtype: int64

# %% [raw]
# There is no null data in our dataset

# %%
#now we separate year from dataset
year = songs.Year
year = year.unique()
yer = np.array(year)
print(np.sort(yer))
# Out:
# [1901 1909 1911 1913 1917 1918 1919 1920 1921 1922 1923 1924 1925 1926
#  1927 1928 1929 1930 1931 1932 1933 1934 1935 1936 1937 1938 1939 1940
#  1941 1942 1943 1944 1945 1946 1947 1948 1949 1950 1951 1952 1953 1954
#  1955 1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967 1968
#  1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982
#  1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996
#  1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010
#  2011 2012 2013 2014]

# %% [raw]
# In our dataset the oldest song is from 1901 and latest song is from 2014

# %% [raw]
# Now we have to find unique artist name

# %%
artist = songs.Artist
artist = artist.unique()
art = np.array(artist)
print(art)
# Out:
# ['Bill Haley & his Comets' 'Celine Dion' "Sinead O'Connor" ...
#  'Lyte Funkie Ones' 'Bob Crosby & his Orchestra' 'Major Lance']

# %%
art.size
# Out:
# 2243

# %%
artists = songs.Artist
arts = artists.value_counts()
arts = arts.head(15)
# Out:
# Artist
# Madonna               48
# Elvis Presley         43
# The Beatles           43
# The Rolling Stones    31
# Michael Jackson       29
# Elton John            28
# Mariah Carey          26
# Bing Crosby           24
# Prince                21
# U2                    21
# Bee Gees              21
# Abba                  20
# Janet Jackson         19
# Glenn Miller          18
# Whitney Houston       18
# Name: count, dtype: int64

# %% [raw]
# As we see in our dataset Madonna have most of the song

# %% [markdown]
# # Madonna

# %%
#so we have to see all madonna's song 
grouped = songs.groupby('Artist')
madona = grouped.get_group('Madonna')
print(madona)
# Out:
#        Artist                          Title  Year   Sales  Streams  \
# 31    Madonna                          Vogue  1990  26.504    9.586
# 61    Madonna                        Hung Up  2005  23.935    6.452
# 98    Madonna                  Like a Prayer  1989  21.992    9.617
# 105   Madonna                          Music  2000  21.688    7.246
# 220   Madonna              Papa Don't Preach  1986  18.398    6.318
# 246   Madonna                         Frozen  1998  17.789    4.579
# 368   Madonna                  Like a Virgin  1984  15.630    9.012
# 373   Madonna                     Take a Bow  1995  15.593    6.776
# 465   Madonna               Who's That Girl?  1987  14.472    4.557
# 548   Madonna                Justify My Love  1990  13.586    6.037
# 566   Madonna  This Used to Be My Playground  1992  13.410    6.582
# 578   Madonna                   American Pie  2000  13.298    1.770
# 583   Madonna                  Crazy For You  1985  13.231    7.135
# ...

# %%
mad = pd.DataFrame(madona)

# %%
mad.head()
# Out:
#       Artist              Title  Year   Sales  Streams  Downloads  \
# 31   Madonna              Vogue  1990  26.504    9.586      8.353
# 61   Madonna            Hung Up  2005  23.935    6.452      5.552
# 98   Madonna      Like a Prayer  1989  21.992    9.617      9.006
# 105  Madonna              Music  2000  21.688    7.246      7.093
# 220  Madonna  Papa Don't Preach  1986  18.398    6.318      9.140
#
#      Radio Plays  Rating
# 31        17.740   2.701
# 61        19.778   2.650
# 98        18.434   2.026
# 105       14.284   2.662
# 220       15.331   0.514

# %%
madyear = mad.Year
mdyear = np.array(madyear)
mdyear = np.sort(mdyear)
print(mdyear)
# Out:
# [1984 1984 1984 1985 1985 1985 1985 1985 1986 1986 1986 1987 1987 1987
#  1989 1989 1989 1990 1990 1990 1990 1991 1992 1992 1993 1993 1994 1994
#  1995 1995 1996 1997 1998 1998 1998 1999 2000 2000 2000 2001 2002 2003
#  2005 2006 2006 2006 2008 2009]

# %% [raw]
# So her first song in datasets is from 1984

# %%
mad.sort_values('Year').head()
# Out:
#        Artist          Title  Year   Sales  Streams  Downloads  Radio Plays  \
# 2393  Madonna     Borderline  1984   6.486    4.653      3.751        2.293
# 368   Madonna  Like a Virgin  1984  15.630    9.012      7.527        6.546
# 2256  Madonna        Holiday  1984   6.712    5.047      2.806        3.516
# 3717  Madonna   Dress You Up  1985   4.978    2.964      1.791        4.439
# 1353  Madonna  Material Girl  1985   9.309    5.391      2.667        5.616
#
#       Rating
# 2393   0.000
# 368    0.643
# 2256   0.000
# 3717   0.000
# 1353   0.526

# %%
mad.sort_values('Year').tail()
# Out:
#        Artist         Title  Year   Sales  Streams  Downloads  Radio Plays  \
# 1063  Madonna         Sorry  2006  10.427    1.468      2.013       11.325
# 3946  Madonna          Jump  2006   4.776    0.722      0.611        5.536
# 4444  Madonna  Get Together  2006   4.404    0.738      0.643        4.877
# 2906  Madonna  Give It 2 Me  2008   5.770    0.518      0.643        6.693
# 3989  Madonna   Celebration  2009   4.747    0.514      0.833        7.542
#
#       Rating
# 1063   1.114
# 3946   0.583
# 4444   0.517
# 2906   0.553
# 3989   0.533

# %%
mad.sort_values('Rating',ascending=False).head(1)
# Out:
#       Artist       Title  Year   Sales  Streams  Downloads  Radio Plays  \
# 373  Madonna  Take a Bow  1995  15.593    6.776      2.063        7.488
#
#      Rating
# 373   2.798

# %%
#now we see which songs of madonna is most downloaded
mad.sort_values('Downloads',ascending=False).head(1)
# Out:
#       Artist            Title  Year   Sales  Streams  Downloads  Radio Plays  \
# 769  Madonna  Into the Groove  1985  12.087     3.08      9.607       13.287
#
#      Rating
# 769     0.0

# %%
#now we have to find which song is mostly Sales 
mad.sort_values('Sales',ascending=False).head(1)
# Out:
#      Artist  Title  Year   Sales  Streams  Downloads  Radio Plays  Rating
# 31  Madonna  Vogue  1990  26.504    9.586      8.353        17.74   2.701

# %% [markdown]
# # Michael Jackson

# %% [raw]
# Now we study about Michael Jackson data first we have to separate it from data set with the help of groupby functions

# %%
grouped = songs.groupby('Artist')
MJ = grouped.get_group('Michael Jackson')
mj = pd.DataFrame(MJ)
mj.head(5)
# Out:
#               Artist                           Title  Year   Sales  Streams  \
# 26   Michael Jackson                     Billie Jean  1983  27.395   12.399
# 126  Michael Jackson                  Black Or White  1991  20.863    6.303
# 146  Michael Jackson                         Beat It  1983  20.326    9.948
# 232  Michael Jackson               You Are Not Alone  1995  18.187    4.582
# 417  Michael Jackson  Don't Stop 'Til You Get Enough  1979  15.097    8.660
#
#      Downloads  Radio Plays  Rating
# 26      11.737       19.010   1.010
# 126      8.542       18.088   2.634
# 146      7.076       15.068   0.625
# 232      6.292       13.548   1.127
# 417      8.767        7.867   0.583

# %%
mjyear = mj.Year
mjyear = mjyear.unique()
mjyears = np.array(mjyear)
print(np.sort(mjyears))
# Out:
# [1971 1972 1979 1980 1981 1983 1984 1987 1988 1989 1991 1992 1993 1995
#  1996 1997 2003]

# %% [raw]
# So we have find that micheal jacksons oldest song in our dataset is from 1971 and latest song is from 2003

# %%
mj.sort_values('Year')
# Out:
#                Artist                           Title  Year   Sales  Streams  \
# 3644  Michael Jackson                 Got to Be There  1971   5.063    5.120
# 1096  Michael Jackson                             Ben  1972  10.280    7.765
# 417   Michael Jackson  Don't Stop 'Til You Get Enough  1979  15.097    8.660
# 3484  Michael Jackson                    Off the Wall  1980   5.212    5.366
# 1535  Michael Jackson                   Rock With You  1980   8.282   10.037
# 2408  Michael Jackson            One Day in Your Life  1981   6.465    0.518
# 26    Michael Jackson                     Billie Jean  1983  27.395   12.399
# 146   Michael Jackson                         Beat It  1983  20.326    9.948
# 2106  Michael Jackson     Wanna Be Startin' Something  1983   7.005    4.691
# 525   Michael Jackson                        Thriller  1984  13.844    7.394
# 870   Michael Jackson                             Bad  1987  11.411    3.860
# ...

# %%
print("Most of the sales music of Micheal Jackson = \n")
mj.sort_values('Sales',ascending=False).head(4)
# Out:
# Most of the sales music of Micheal Jackson =
#               Artist              Title  Year   Sales  Streams  Downloads  \
# 26   Michael Jackson        Billie Jean  1983  27.395   12.399     11.737
# 126  Michael Jackson     Black Or White  1991  20.863    6.303      8.542
# 146  Michael Jackson            Beat It  1983  20.326    9.948      7.076
# 232  Michael Jackson  You Are Not Alone  1995  18.187    4.582      6.292
#
#      Radio Plays  Rating
# 26        19.010   1.010
# 126       18.088   2.634
# 146       15.068   0.625
# 232       13.548   1.127

# %%
print("Least song sold of Micheal Jackson music = \n")
mj.sort_values('Sales',ascending=True).head(4)
# Out:
# Least song sold of Micheal Jackson music =
#                Artist               Title  Year  Sales  Streams  Downloads  \
# 4653  Michael Jackson           Who is It  1992  4.271    1.096       0.60
# 4619  Michael Jackson     One More Chance  2003  4.290    0.712       0.70
# 4513  Michael Jackson  Stranger in Moscow  1996  4.358    0.511       0.75
# 4499  Michael Jackson      Leave Me Alone  1989  4.370    1.100       2.50
#
#       Radio Plays  Rating
# 4653        6.656   0.523
# 4619        2.155   1.500
# 4513        5.791   0.534
# 4499        6.090   0.000

# %%
print("Songs of micheal jacksons having high rating = ")
mj.sort_values('Rating',ascending=False).head(4)
# Out:
# Songs of micheal jacksons having high rating =
#                Artist                     Title  Year   Sales  Streams  \
# 126   Michael Jackson            Black Or White  1991  20.863    6.303
# 894   Michael Jackson         Remember the Time  1992  11.264    4.884
# 1097  Michael Jackson  Blood on the Dance Floor  1997  10.259    1.237
# 4619  Michael Jackson           One More Chance  2003   4.290    0.712
#
#       Downloads  Radio Plays  Rating
# 126       8.542       18.088   2.634
# 894       2.333        8.509   2.049
# 1097      3.526        8.115   2.010
# 4619      0.700        2.155   1.500

# %%
print("Micheal Jacksons' song that played mostly in radio = ")
mj.sort_values('Radio Plays',ascending=False).head(4)
# Out:
# Micheal Jacksons' song that played mostly in radio =
#                Artist           Title  Year   Sales  Streams  Downloads  \
# 26    Michael Jackson     Billie Jean  1983  27.395   12.399     11.737
# 126   Michael Jackson  Black Or White  1991  20.863    6.303      8.542
# 1231  Michael Jackson      Earth Song  1995   9.687    0.200      2.903
# 146   Michael Jackson         Beat It  1983  20.326    9.948      7.076
#
#       Radio Plays  Rating
# 26         19.010   1.010
# 126        18.088   2.634
# 1231       17.110   0.000
# 146        15.068   0.625

# %%
print("Most of the song downloaded = ")
mj.sort_values('Downloads',ascending=False).head(3)
# Out:
# Most of the song downloaded =
#               Artist                           Title  Year   Sales  Streams  \
# 26   Michael Jackson                     Billie Jean  1983  27.395   12.399
# 417  Michael Jackson  Don't Stop 'Til You Get Enough  1979  15.097    8.660
# 126  Michael Jackson                  Black Or White  1991  20.863    6.303
#
#      Downloads  Radio Plays  Rating
# 26      11.737       19.010   1.010
# 417      8.767        7.867   0.583
# 126      8.542       18.088   2.634

# %% [markdown]
# # Eminem

# %%
grouped = songs.groupby('Artist')
Eminem = grouped.get_group('Eminem')
Eminem
# Out:
#       Artist                   Title  Year   Sales  Streams  Downloads  \
# 11    Eminem           Lose Yourself  2002  30.554   12.994      7.143
# 34    Eminem              Without Me  2002  26.225    8.266      8.085
# 280   Eminem                    Stan  2000  17.191    3.681      6.735
# 479   Eminem            Just Lose It  2004  14.340    3.613      5.032
# 547   Eminem     The Real Slim Shady  2000  13.591    5.371      4.101
# 1673  Eminem           When I'm Gone  2006   7.907    2.403      2.772
# 1778  Eminem             We Made You  2009   7.656    1.511      5.788
# 2201  Eminem     Sing For the Moment  2003   6.813    2.813      0.667
# 2400  Eminem       Like Toy Soldiers  2005   6.473    1.279      1.500
# 2433  Eminem  Cleanin' Out My Closet  2002   6.427    3.065      1.276
# 2610  Eminem              My Name Is  1999   6.166    2.913      1.629
# 3687  Eminem             Mockingbird  2005   5.017    3.424      0.750
#
#       Radio Plays  Rating
# ...

# %%
Eminem.sort_values(['Year'],ascending=True)
# Out:
#       Artist                   Title  Year   Sales  Streams  Downloads  \
# 2610  Eminem              My Name Is  1999   6.166    2.913      1.629
# 280   Eminem                    Stan  2000  17.191    3.681      6.735
# 547   Eminem     The Real Slim Shady  2000  13.591    5.371      4.101
# 11    Eminem           Lose Yourself  2002  30.554   12.994      7.143
# 34    Eminem              Without Me  2002  26.225    8.266      8.085
# 2433  Eminem  Cleanin' Out My Closet  2002   6.427    3.065      1.276
# 2201  Eminem     Sing For the Moment  2003   6.813    2.813      0.667
# 479   Eminem            Just Lose It  2004  14.340    3.613      5.032
# 2400  Eminem       Like Toy Soldiers  2005   6.473    1.279      1.500
# 3687  Eminem             Mockingbird  2005   5.017    3.424      0.750
# 1673  Eminem           When I'm Gone  2006   7.907    2.403      2.772
# 1778  Eminem             We Made You  2009   7.656    1.511      5.788
#
#       Radio Plays  Rating
# ...

# %% [markdown]
# # ABBA

# %% [raw]
# Now we analyse data of band named "ABBA" which is most famous band in 70s

# %%
grouped = songs.groupby('Artist')
ABBA = grouped.get_group('Abba')
ABBA
# Out:
#      Artist                                        Title  Year   Sales  \
# 22     Abba                                Dancing Queen  1976  27.582
# 161    Abba                                     Waterloo  1974  19.544
# 165    Abba                                     Fernando  1976  19.470
# 328    Abba                                          SOS  1975  16.122
# 508    Abba                      The Winner Takes it All  1980  14.052
# 710    Abba                          Money, Money, Money  1976  12.414
# 765    Abba                      Knowing Me, Knowing You  1977  12.101
# 786    Abba                          Take a Chance On Me  1978  12.012
# 818    Abba                                   Chiquitita  1979  11.787
# 1108   Abba                 I Do, I Do, I Do, I Do, I Do  1975  10.224
# 1114   Abba                                    Mamma Mia  1976  10.188
# 1300   Abba                                Super Trouper  1980   9.498
# ...

# %%
Abba = pd.DataFrame(ABBA)
Abba
# Out:
#      Artist                                        Title  Year   Sales  \
# 22     Abba                                Dancing Queen  1976  27.582
# 161    Abba                                     Waterloo  1974  19.544
# 165    Abba                                     Fernando  1976  19.470
# 328    Abba                                          SOS  1975  16.122
# 508    Abba                      The Winner Takes it All  1980  14.052
# 710    Abba                          Money, Money, Money  1976  12.414
# 765    Abba                      Knowing Me, Knowing You  1977  12.101
# 786    Abba                          Take a Chance On Me  1978  12.012
# 818    Abba                                   Chiquitita  1979  11.787
# 1108   Abba                 I Do, I Do, I Do, I Do, I Do  1975  10.224
# 1114   Abba                                    Mamma Mia  1976  10.188
# 1300   Abba                                Super Trouper  1980   9.498
# ...

# %%
#now we find unique year of Abba dataset
Abbayear = Abba.Year
Ay = Abbayear.unique()
Ay = np.array(Ay)
print(np.sort(Ay))
# Out:
# [1973 1974 1975 1976 1977 1978 1979 1980 1981 1982]

# %%
Abba.sort_values('Year')
# Out:
#      Artist                                        Title  Year   Sales  \
# 3872   Abba                                    Ring Ring  1973   4.842
# 161    Abba                                     Waterloo  1974  19.544
# 1108   Abba                 I Do, I Do, I Do, I Do, I Do  1975  10.224
# 328    Abba                                          SOS  1975  16.122
# 1114   Abba                                    Mamma Mia  1976  10.188
# 22     Abba                                Dancing Queen  1976  27.582
# 165    Abba                                     Fernando  1976  19.470
# 710    Abba                          Money, Money, Money  1976  12.414
# 765    Abba                      Knowing Me, Knowing You  1977  12.101
# 1479   Abba                         The Name of the Game  1977   8.425
# 786    Abba                          Take a Chance On Me  1978  12.012
# 2480   Abba                            Summer Night City  1978   6.373
# ...

# %%
print("Highest rating song = ")
Abba.sort_values('Rating',ascending=False).head(1)
# Out:
# Highest rating song =
#     Artist       Title  Year   Sales  Streams  Downloads  Radio Plays  Rating
# 818   Abba  Chiquitita  1979  11.787    1.282      8.309       10.935   1.106

# %%
print("Mostly played song on radio = ")
Abba.sort_values('Radio Plays',ascending=False).head(1)
# Out:
# Mostly played song on radio =
#     Artist     Title  Year   Sales  Streams  Downloads  Radio Plays  Rating
# 161   Abba  Waterloo  1974  19.544    6.399      7.007       17.425    0.01

# %%
print("Highest Sales = ")
Abba.sort_values('Sales',ascending=False).head(1)
# Out:
# Highest Sales =
#    Artist          Title  Year   Sales  Streams  Downloads  Radio Plays  \
# 22   Abba  Dancing Queen  1976  27.582    13.63     14.391       16.401
#
#     Rating
# 22   0.537

# %% [markdown]
# # Now we analyse whole datasets

# %%
songs.head(6)
# Out:
#                     Artist                              Title  Year   Sales  \
# 0  Bill Haley & his Comets              Rock Around the Clock  1955  36.503
# 1              Celine Dion                My Heart Will Go On  1998  35.405
# 2          Sinead O'Connor               Nothing Compares 2 U  1990  35.135
# 3              The Beatles                           Hey Jude  1968  34.442
# 4              Bryan Adams  (Everything I Do) I Do it For You  1991  34.367
# 5          Whitney Houston             I Will Always Love You  1992  34.112
#
#    Streams  Downloads  Radio Plays  Rating
# 0   19.961      7.458        5.663   0.760
# 1   12.636      8.944       23.701   3.610
# 2   14.582     10.242       23.747   2.733
# 3   25.545     16.390       16.541   1.510
# 4   16.523     12.368       23.194   3.121
# 5   14.873     11.290       20.753   4.460

# %% [markdown]
# # Top 10 Oldest Song

# %%
songs.sort_values('Year').head(10)
# Out:
# Top 10 Oldest song =
#                                Artist  \
# 2057                     Sousa's Band
# 3231  Fisk University Jubilee Quartet
# 1972                    Sophie Tucker
# 3547                   Chauncy Olcott
# 3096                       Nora Bayes
# 3321                 American Quartet
# 1676     Original Dixieland Jazz Band
# 3589                        Al Jolson
# 3091                    Marion Harris
# 3990                       Ben Selvin
#
#                                            Title  Year  Sales  Streams  \
# 2057                     Stars & Stripes Forever  1901  7.097    5.883
# 3231                    Swing Low, Sweet Chariot  1909  5.444    5.423
# 1972                          Some of These Days  1911  7.254    6.059
# 3547                 When Irish Eyes Are Smiling  1913  5.150    3.832
# 3096                                  Over There  1917  5.571    4.500
# 3321                                  Over There  1917  5.356    4.226
# ...

# %%
print("Top 10 song have highest ratings = ")
songs.sort_values('Rating',ascending=False).head(10)
# Out:
# Top 10 song have highest ratings =
#               Artist                              Title  Year   Sales  \
# 5    Whitney Houston             I Will Always Love You  1992  34.112
# 58       Ace of Base                           The Sign  1994  24.202
# 1        Celine Dion                My Heart Will Go On  1998  35.405
# 30            Hanson                             Mmmbop  1997  26.574
# 157    Avril Lavigne                         Girlfriend  2007  19.834
# 65      Ricky Martin                Livin' La Vida Loca  1999  23.729
# 8         Elton John             Candle in the Wind '97  1997  31.054
# 4        Bryan Adams  (Everything I Do) I Do it For You  1991  34.367
# 40       Los Del Rio                           Macarena  1996  25.687
# 173      Boyz II Men              I'll Make Love to You  1994  19.291
#
#      Streams  Downloads  Radio Plays  Rating
# 5     14.873     11.290       20.753   4.460
# 58     9.274      6.950       12.405   3.833
# ...

# %%
print("Top 10 highest Downloaded Song = ")
songs.sort_values('Downloads',ascending=False).head(10)
# Out:
# Top 10 highest Downloaded Song =
#                                  Artist  \
# 44                                Queen
# 38                          John Lennon
# 3                           The Beatles
# 79                         Culture Club
# 15                         Procol Harum
# 123               Elton John & Kiki Dee
# 84                  Tony Orlando & Dawn
# 28   John Travolta & Olivia Newton-John
# 66                          The Monkees
# 21                      George Harrison
#
#                                            Title  Year   Sales  Streams  \
# 44                             Bohemian Rhapsody  1976  25.468   11.819
# 38                                       Imagine  1971  25.732   14.567
# 3                                       Hey Jude  1968  34.442   25.545
# 79                               Karma Chameleon  1983  22.967    7.164
# 15                        A Whiter Shade of Pale  1967  29.428   12.018
# ...

# %% [markdown]
# # Top 10 higest Sales record song

# %%
songs.sort_values('Sales',ascending=False).head(10)
# Out:
# Top 10 highest Sales record =
#                     Artist                               Title  Year   Sales  \
# 0  Bill Haley & his Comets               Rock Around the Clock  1955  36.503
# 1              Celine Dion                 My Heart Will Go On  1998  35.405
# 2          Sinead O'Connor                Nothing Compares 2 U  1990  35.135
# 3              The Beatles                            Hey Jude  1968  34.442
# 4              Bryan Adams   (Everything I Do) I Do it For You  1991  34.367
# 5          Whitney Houston              I Will Always Love You  1992  34.112
# 6               Pink Floyd  Another Brick in the Wall (part 2)  1980  32.020
# 7               Irene Cara        Flashdance... What a Feeling  1983  31.305
# 9       The Rolling Stones       (I Can't Get No) Satisfaction  1965  31.054
# 8               Elton John              Candle in the Wind '97  1997  31.054
#
#    Streams  Downloads  Radio Plays  Rating
# 0   19.961      7.458        5.663   0.760
# ...

# %% [markdown]
# # Top 10 latest song

# %%
songs.sort_values('Year',ascending=False).head(10)
# Out:
#                        Artist                Title  Year   Sales  Streams  \
# 3811                Sam Smith         Stay With Me  2014   4.897    2.225
# 1886        Pharrell Williams                Happy  2014   7.418    4.967
# 4305              Nico & Vinz           Am I Wrong  2014   4.511    1.745
# 3397           Meghan Trainor  All About That Bass  2014   5.280    2.439
# 1071                    Lorde               Royals  2013  10.390    6.666
# 1176               Katy Perry                 Roar  2013   9.912    4.808
# 3327                   Avicii         Hey, Brother  2013   5.352    1.564
# 2237                Passenger           Let Her Go  2013   6.755    1.603
# 2379        Justin Timberlake              Mirrors  2013   6.509    5.508
# 3787  Macklemore & Ryan Lewis            Same Love  2013   4.916    3.591
#
#       Downloads  Radio Plays  Rating
# 3811      3.625        1.500     0.0
# 1886      4.500        1.500     0.0
# 4305      3.563        1.500     0.0
# ...

# %% [markdown]
# # Top 10 Songs that are mostly played on radio

# %%
songs.sort_values('Radio Plays',ascending=False).head(10)
# Out:
#                Artist                               Title  Year   Sales  \
# 36      Stevie Wonder     I Just Called to Say I Love You  1984  25.939
# 2     Sinead O'Connor                Nothing Compares 2 U  1990  35.135
# 1         Celine Dion                 My Heart Will Go On  1998  35.405
# 45   Barbra Streisand                     A Woman in Love  1980  25.365
# 6          Pink Floyd  Another Brick in the Wall (part 2)  1980  32.020
# 411         F R David                               Words  1982  15.187
# 4         Bryan Adams   (Everything I Do) I Do it For You  1991  34.367
# 83         The Fugees     Killing Me Softly With His Song  1996  22.861
# 10             Coolio                  Gangsta's Paradise  1995  30.822
# 125           Boney M                   Rivers of Babylon  1978  20.873
#
#      Streams  Downloads  Radio Plays  Rating
# 36     8.760     13.416       24.393   0.833
# 2     14.582     10.242       23.747   2.733
# ...

# %% [markdown]
# # Songs that least Downloaded

# %%
songs.sort_values('Downloads',ascending=True).head(10)
# Out:
#                           Artist  \
# 785   Fred Astaire & Leo Reisman
# 2762                 Johnny Cash
# 3544                 Bill Monroe
# 2756                 Harry James
# 669                   Artie Shaw
# 2740            Three Doors Down
# 4120              Billie Holiday
# 2728             Mahalia Jackson
# 2723                Jimmy Dorsey
# 3559               Vaughn Monroe
#
#                                                  Title  Year   Sales  Streams  \
# 785                                        Night & Day  1932  12.013   10.331
# 2762                                   I Walk the Line  1956   5.946    8.995
# 3544                             Blue Moon of Kentucky  1947   5.151    5.736
# 2756     You Made Me Love You (I Didn't Want to Do It)  1941   5.956    5.525
# 669                                            Frenesi  1940  12.661   10.072
# 2740                                        Kryptonite  2000   5.975    6.433
# ...

# %% [markdown]
# # Top 10 songs that are recently release and least downloaded

# %%
sng = songs.sort_values('Year',ascending=False).head(10)
sngi = sng.sort_values('Downloads',ascending=True).head(10)
sngi
# Out:
#                        Artist                Title  Year   Sales  Streams  \
# 2379        Justin Timberlake              Mirrors  2013   6.509    5.508
# 3327                   Avicii         Hey, Brother  2013   5.352    1.564
# 3787  Macklemore & Ryan Lewis            Same Love  2013   4.916    3.591
# 4305              Nico & Vinz           Am I Wrong  2014   4.511    1.745
# 3811                Sam Smith         Stay With Me  2014   4.897    2.225
# 2237                Passenger           Let Her Go  2013   6.755    1.603
# 3397           Meghan Trainor  All About That Bass  2014   5.280    2.439
# 1886        Pharrell Williams                Happy  2014   7.418    4.967
# 1071                    Lorde               Royals  2013  10.390    6.666
# 1176               Katy Perry                 Roar  2013   9.912    4.808
#
#       Downloads  Radio Plays  Rating
# 2379      0.521        2.018     0.0
# 3327      0.536        5.011     0.0
# 3787      2.071        0.511     0.0
# ...

# %% [markdown]
# # Now we pick another artist  = Elvis Presley

# %%
grouped = songs.groupby('Artist')
ElvisP = grouped.get_group('Elvis Presley')
ElvisP
# Out:
#              Artist                                  Title  Year   Sales  \
# 41    Elvis Presley              Are You Lonesome Tonight?  1960  25.657
# 48    Elvis Presley                      It's Now Or Never  1960  25.254
# 62    Elvis Presley                         Jailhouse Rock  1957  23.827
# 216   Elvis Presley                       Heartbreak Hotel  1956  18.448
# 218   Elvis Presley                       Suspicious Minds  1969  18.423
# 245   Elvis Presley                              Hound Dog  1956  17.840
# 310   Elvis Presley                           All Shook Up  1957  16.347
# 326   Elvis Presley                         Don't Be Cruel  1956  16.150
# 349   Elvis Presley                              Surrender  1961  15.784
# 361   Elvis Presley                       Return to Sender  1962  15.671
# 381   Elvis Presley  (Now & then There's) A Fool Such As I  1959  15.525
# 449   Elvis Presley             Can't Help Falling in Love  1962  14.678
# ...

# %%
Elvis = ElvisP.Year
Elvis = Elvis.unique()
elvis = np.array(Elvis)
print(np.sort(elvis))
# Out:
# [1954 1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1969 1970 1972
#  2003]

# %% [raw]
# Oldest song of Elvis Presely = 1954
# And New song of Elvis Presely = 2003 !! I dont know why elvis presely dead in late 70s

# %% [markdown]
# # Now we analyse Elvis Presley data

# %%
#but first we have to save in data frame
EP = pd.DataFrame(ElvisP)
EP.head()
# Out:
#             Artist                      Title  Year   Sales  Streams  \
# 41   Elvis Presley  Are You Lonesome Tonight?  1960  25.657   12.057
# 48   Elvis Presley          It's Now Or Never  1960  25.254    9.789
# 62   Elvis Presley             Jailhouse Rock  1957  23.827   13.312
# 216  Elvis Presley           Heartbreak Hotel  1956  18.448   15.536
# 218  Elvis Presley           Suspicious Minds  1969  18.423   14.456
#
#      Downloads  Radio Plays  Rating
# 41       9.198        7.590   0.010
# 48      11.625        6.587   0.667
# 62       6.294        4.537   0.010
# 216      2.295        1.163   0.527
# 218     14.570        5.653   0.522

# %% [markdown]
# # Highest Rating song

# %%
EP.sort_values('Rating',ascending=False).head(10)
# Out:
#              Artist                     Title  Year   Sales  Streams  \
# 48    Elvis Presley         It's Now Or Never  1960  25.254    9.789
# 349   Elvis Presley                 Surrender  1961  15.784    4.716
# 245   Elvis Presley                 Hound Dog  1956  17.840   14.892
# 1562  Elvis Presley  I Need Your Love Tonight  1959   8.203    2.503
# 326   Elvis Presley            Don't Be Cruel  1956  16.150   14.351
# 800   Elvis Presley            Love Me Tender  1956  11.907   10.950
# 3017  Elvis Presley             Rubberneckin'  2003   5.656    1.411
# 2572  Elvis Presley          Rock a Hula Baby  1962   6.228    0.745
# 1780  Elvis Presley              Burning Love  1972   7.654    6.819
# 3733  Elvis Presley               King Creole  1958   4.963    0.713
#
#       Downloads  Radio Plays  Rating
# 48       11.625        6.587   0.667
# 349       8.602        5.217   0.653
# 245       1.667        1.608   0.569
# 1562      4.500        1.000   0.559
# ...

# %% [markdown]
# # Song that mostly played in radio

# %%
EP.sort_values('Radio Plays',ascending=False).head(10)
# Out:
#              Artist                           Title  Year   Sales  Streams  \
# 452   Elvis Presley                   In the Ghetto  1969  14.623    9.112
# 41    Elvis Presley       Are You Lonesome Tonight?  1960  25.657   12.057
# 495   Elvis Presley  (You're The) Devil in Disguise  1963  14.158    4.374
# 726   Elvis Presley                    Wooden Heart  1961  12.307    0.201
# 48    Elvis Presley               It's Now Or Never  1960  25.254    9.789
# 218   Elvis Presley                Suspicious Minds  1969  18.423   14.456
# 1867  Elvis Presley                   Kiss Me Quick  1963   7.447    1.264
# 349   Elvis Presley                       Surrender  1961  15.784    4.716
# 499   Elvis Presley                 Good Luck Charm  1962  14.123    6.413
# 361   Elvis Presley                Return to Sender  1962  15.671    7.172
#
#       Downloads  Radio Plays  Rating
# 452      10.503       10.035   0.000
# 41        9.198        7.590   0.010
# ...

# %% [markdown]
# # Song that are highest sales record

# %%
EP.sort_values('Sales',ascending=False).head(10)
# Out:
#             Artist                      Title  Year   Sales  Streams  \
# 41   Elvis Presley  Are You Lonesome Tonight?  1960  25.657   12.057
# 48   Elvis Presley          It's Now Or Never  1960  25.254    9.789
# 62   Elvis Presley             Jailhouse Rock  1957  23.827   13.312
# 216  Elvis Presley           Heartbreak Hotel  1956  18.448   15.536
# 218  Elvis Presley           Suspicious Minds  1969  18.423   14.456
# 245  Elvis Presley                  Hound Dog  1956  17.840   14.892
# 310  Elvis Presley               All Shook Up  1957  16.347    9.971
# 326  Elvis Presley             Don't Be Cruel  1956  16.150   14.351
# 349  Elvis Presley                  Surrender  1961  15.784    4.716
# 361  Elvis Presley           Return to Sender  1962  15.671    7.172
#
#      Downloads  Radio Plays  Rating
# 41       9.198        7.590   0.010
# 48      11.625        6.587   0.667
# 62       6.294        4.537   0.010
# 216      2.295        1.163   0.527
# ...

# %% [markdown]
# # Latest song of Elvis Presley

# %%
EP.sort_values('Year',ascending=False).head(1)
# Out:
#              Artist          Title  Year  Sales  Streams  Downloads  \
# 3017  Elvis Presley  Rubberneckin'  2003  5.656    1.411      1.952
#
#       Radio Plays  Rating
# 3017        3.384   0.548

# %% [markdown]
# # Oldest song of Elvis Presley

# %%
EP.sort_values('Year',ascending=True).head(1)
# Out:
#              Artist             Title  Year  Sales  Streams  Downloads  \
# 4006  Elvis Presley  That's All Right  1954  4.733    4.727      0.833
#
#       Radio Plays  Rating
# 4006          0.0     0.0
